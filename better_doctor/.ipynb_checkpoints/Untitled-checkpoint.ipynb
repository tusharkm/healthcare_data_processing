# %%
import pandas as pd
import os
CSV_FILEPATH='./data_files/match_file.csv'
JSON_FILEPATH='./data_files/source_data.json'


csv_file=pd.read_csv(CSV_FILEPATH)
json_file=pd.read_json(JSON_FILEPATH,lines=True)

# %%
json_file
# Out:
#                                                   doctor  \
# 0      {'first_name': 'Dean', 'npi': '851030801437847...
# 1      {'first_name': 'Quinton', 'npi': '362333835423...
# 2      {'first_name': 'Vincent', 'npi': '689518261216...
# 3      {'first_name': 'Gerardo', 'npi': '924428057827...
# 4      {'first_name': 'Dean', 'npi': '830291517155783...
# 5      {'first_name': 'Marshall', 'npi': '18233577393...
# 6      {'first_name': 'Lawson', 'npi': '7879278827541...
# 7      {'first_name': 'Coty', 'npi': '503915142472377...
# 8      {'first_name': 'Billy', 'npi': '10032670447666...
# 9      {'first_name': 'Deion', 'npi': '36556623055822...
# 10     {'first_name': 'Zena', 'npi': '028611192667222...
# 11     {'first_name': 'Dallin', 'npi': '5253588213358...
# 12     {'first_name': 'Emelia', 'npi': '6304831945201...
# 13     {'first_name': 'Clyde', 'npi': '87766177950596...
# 14     {'first_name': 'Dannie', 'npi': '1248988753407...
# ...

# %%
from pandas.io.json import json_normalize

# %%
json_file=pd.read_json(JSON_FILEPATH,lines=True)

# %%
json_file.to_dict('records')
# Out:
# [{'doctor': {'first_name': 'Dean',
#    'last_name': 'Israel',
#    'npi': '85103080143784778415'},
#   'practices': [{'city': 'Port Demetris',
#     'lat': '-79.8757664338564',
#     'lon': '84.31253504872467',
#     'state': 'LA',
#     'street': '271 Annabelle Fort',
#     'street_2': 'Apt. 404',
#     'zip': '53549'}]},
#  {'doctor': {'first_name': 'Quinton',
#    'last_name': 'Mollie',
#    'npi': '36233383542350521233'},
#   'practices': [{'city': 'Nealville',
#     'lat': '81.37417480720865',
#     'lon': '-95.33450729432164',
#     'state': 'OR',
#     'street': '8496 Kennedi Inlet',
#     'street_2': 'Suite 815',
#     'zip': '52665-6811'},
#    {'city': 'Rashadborough',
#     'lat': '69.84837521604314',
#     'lon': '87.36942972635728',
#     'state': 'UT',
#     'street': '29483 Nader Wall',
#     'street_2': 'Apt. 748',
#     'zip': '46006-3437'},
#    {'city': 'South Daronland',
#     'lat': '84.90377842497296',
#     'lon': '177.28706015725533',
#     'state': 'AK',
# ...

# %%
df1 = pd.io.json.json_normalize(json_file.to_dict('records'))

# %%
df2 = pd.io.json.json_normalize(df1.practices.apply(lambda x: x[0]).tolist())

# %%
df2
# Out:
#                      city                  lat                  lon state  \
# 0           Port Demetris    -79.8757664338564    84.31253504872467    LA
# 1               Nealville    81.37417480720865   -95.33450729432164    OR
# 2         West Lonnieberg    52.12502086274685   109.12414094328233    GA
# 3            Grantborough    78.53231427000821   12.229188372184922    MN
# 4               New Fredy   -4.541598251928605   -41.46795232079714    IL
# 5             Lake Sheila     67.8952178905721   -71.54982356539455    AZ
# 6             North Daija  -5.6687886642665575   -78.53360129963642    DE
# 7        West Calistaside   -58.29709418783973   -90.33104012263043    ND
# 8           West Penelope  -26.051512799700845   -142.5655398712161    OK
# 9          Streichchester   14.435512034467493  -17.361548051772843    AZ
# 10      Macejkovicborough   30.162134795190568   -90.50020614602697    IA
# 11            Fernchester    83.27744784461902   -7.588193564781278    ID
# ...

# %%
df1['city'] = df2.city
df1['lat'] = df2.lat
df1['lat'] = df2.lat
df1['state'] = df2.state
df1['street'] = df2.street
df1['street_2'] = df2.street_2
df1['zip'] = df2.zip

# %%
df1 = df1.drop(['practices'], 1).copy()

# %%
df1.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi             city  \
# 0              Dean           Israel  85103080143784778415    Port Demetris
# 1           Quinton           Mollie  36233383542350521233        Nealville
# 2           Vincent            Abbie  68951826121607537145  West Lonnieberg
# 3           Gerardo            Piper  92442805782715742535     Grantborough
# 4              Dean        Francesco  83029151715578341587        New Fredy
#
#                   lat state                  street   street_2         zip
# 0   -79.8757664338564    LA      271 Annabelle Fort   Apt. 404       53549
# 1   81.37417480720865    OR      8496 Kennedi Inlet  Suite 815  52665-6811
# 2   52.12502086274685    GA        210 Walsh Island  Suite 839       59104
# 3   78.53231427000821    MN       1262 O'Keefe Ford   Apt. 790       39283
# 4  -4.541598251928605    IL  98764 Mante Trafficway  Suite 356       43570

# %%
missing_df = df1.isnull().sum(axis=0).reset_index()

# %%
missing_df.columns = ['column_name', 'missing_count']

# %%
missing_df.columns = ['column_name', 'missing_count']
missing_df = missing_df.loc[missing_df['missing_count']>0]

# %%
missing_df
# Out:
# Empty DataFrame
# Columns: [column_name, missing_count]
# Index: []

# %%
csv_file=pd.read_csv(CSV_FILEPATH)
csv_file.head()
# Out:
#   first_name last_name                   npi                street   street_2  \
# 0      Ruthe   Laverne  44843147983186317848    569 glenda islands  suite 163
# 1   Marshall      Cole  18233577393219566041  59944 adaline harbor   apt. 862
# 2     Lawson  Lilliana  78792788275411915642     36175 amina mount   apt. 256
# 3    Martine     Kiana  23583155472740817761        188 walsh flat   apt. 891
# 4     Leatha    Freida                   NaN  43796 gutmann plains  suite 341
#
#           city state         zip
# 0     willport    nj       23453
# 1  keelingstad    al  94189-5965
# 2  north daija    de  30997-4476
# 3  yasmeenstad    nv       83568
# 4     vonmouth    fl       10500

# %%
    missing_df = csv_file.isnull().sum(axis=0).reset_index()

# %%
missing_df
# Out:
#         index    0
# 0  first_name    0
# 1   last_name    0
# 2         npi  287
# 3      street  230
# 4    street_2  230
# 5        city  230
# 6       state  230
# 7         zip  230

# %%
missing_df.columns = ['column_name', 'missing_count']

# %%
missing_df.columns = ['column_name', 'missing_count']
missing_df = missing_df.loc[missing_df['missing_count']>0]

# %%
missing_df
# Out:
#   column_name  missing_count
# 2         npi            287
# 3      street            230
# 4    street_2            230
# 5        city            230
# 6       state            230
# 7         zip            230

# %%
csv_file.shape
# Out:
# (1265, 8)

# %%
csv_file.dropna(inplace=True)

# %%
csv_file.shape
#csv_file.head()
# Out:
# (805, 8)

# %%
merged_df = pd.merge( df1,csv_file, left_on = 'doctor.npi', right_on = 'npi', how='inner')

# %%
print(merged_df.shape)
# Out:
# (691, 17)

# %%
merged_df.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi        city_x  \
# 0          Marshall             Cole  18233577393219566041   Lake Sheila
# 1            Lawson         Lilliana  78792788275411915642   North Daija
# 2           Martine            Kiana  23583155472740817761  Jacquesville
# 3         Granville           Benton  17871640342222098849   Octaviastad
# 4            Brenda            Lenna  88137148807320232511  Lisandrofort
#
#                    lat state_x           street_x street_2_x       zip_x  \
# 0     67.8952178905721      AZ  729 Reuben Stream   Apt. 314       85355
# 1  -5.6687886642665575      DE  36175 Amina Mount   Apt. 256  30997-4476
# 2   35.947411051729944      NE     114 Kyra Mills   Apt. 482  89703-1741
# 3   46.184575751643024      IL     95496 Dare Rue  Suite 203  45294-0751
# 4   -20.53963944114676      NM   2625 Borer Pines  Suite 886  44547-0330
#
#   first_name last_name                   npi              street_y street_2_y  \
# ...

# %%
df2.shape
# Out:
# (11231, 7)

# %%
csv_file['name_address'] = csv_file['first_name'] +'_' + csv_file['last_name'] + '_' + csv_file['street']+ '_' + csv_file['street_2']+ '_' + csv_file['city']+ '_' + csv_file['state']+'_' + csv_file['zip']

# %%
csv_file.shape
# Out:
# (805, 9)

# %%
csv_file.head()
# Out:
#   first_name last_name                   npi                street   street_2  \
# 0      Ruthe   Laverne  44843147983186317848    569 glenda islands  suite 163
# 1   Marshall      Cole  18233577393219566041  59944 adaline harbor   apt. 862
# 2     Lawson  Lilliana  78792788275411915642     36175 amina mount   apt. 256
# 3    Martine     Kiana  23583155472740817761        188 walsh flat   apt. 891
# 6  Granville    Benton  17871640342222098849        95496 dare rue  suite 203
#
#           city state         zip  \
# 0     willport    nj       23453
# 1  keelingstad    al  94189-5965
# 2  north daija    de  30997-4476
# 3  yasmeenstad    nv       83568
# 6  octaviastad    il  45294-0751
#
#                                         name_address
# 0  Ruthe_Laverne_569 glenda islands_suite 163_wil...
# 1  Marshall_Cole_59944 adaline harbor_apt. 862_ke...
# 2  Lawson_Lilliana_36175 amina mount_apt. 256_nor...
# 3  Martine_Kiana_188 walsh flat_apt. 891_yasmeens...
# ...

# %%
df2.head()
# Out:
#               city                 lat                 lon state  \
# 0    Port Demetris   -79.8757664338564   84.31253504872467    LA
# 1        Nealville   81.37417480720865  -95.33450729432164    OR
# 2  West Lonnieberg   52.12502086274685  109.12414094328233    GA
# 3     Grantborough   78.53231427000821  12.229188372184922    MN
# 4        New Fredy  -4.541598251928605  -41.46795232079714    IL
#
#                    street   street_2         zip
# 0      271 Annabelle Fort   Apt. 404       53549
# 1      8496 Kennedi Inlet  Suite 815  52665-6811
# 2        210 Walsh Island  Suite 839       59104
# 3       1262 O'Keefe Ford   Apt. 790       39283
# 4  98764 Mante Trafficway  Suite 356       43570

# %%
df1.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi             city  \
# 0              Dean           Israel  85103080143784778415    Port Demetris
# 1           Quinton           Mollie  36233383542350521233        Nealville
# 2           Vincent            Abbie  68951826121607537145  West Lonnieberg
# 3           Gerardo            Piper  92442805782715742535     Grantborough
# 4              Dean        Francesco  83029151715578341587        New Fredy
#
#                   lat state                  street   street_2         zip
# 0   -79.8757664338564    LA      271 Annabelle Fort   Apt. 404       53549
# 1   81.37417480720865    OR      8496 Kennedi Inlet  Suite 815  52665-6811
# 2   52.12502086274685    GA        210 Walsh Island  Suite 839       59104
# 3   78.53231427000821    MN       1262 O'Keefe Ford   Apt. 790       39283
# 4  -4.541598251928605    IL  98764 Mante Trafficway  Suite 356       43570

# %%
df1['name_address'] = df1['doctor.first_name'] +'_' + df1['doctor.last_name'] + '_' + df1['street']+ '_' + df1['street_2']+ '_' + df1['city']+ '_' + df1['state']+'_' + df1['zip']

# %%
df1.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi             city  \
# 0              Dean           Israel  85103080143784778415    Port Demetris
# 1           Quinton           Mollie  36233383542350521233        Nealville
# 2           Vincent            Abbie  68951826121607537145  West Lonnieberg
# 3           Gerardo            Piper  92442805782715742535     Grantborough
# 4              Dean        Francesco  83029151715578341587        New Fredy
#
#                   lat state                  street   street_2         zip  \
# 0   -79.8757664338564    LA      271 Annabelle Fort   Apt. 404       53549
# 1   81.37417480720865    OR      8496 Kennedi Inlet  Suite 815  52665-6811
# 2   52.12502086274685    GA        210 Walsh Island  Suite 839       59104
# 3   78.53231427000821    MN       1262 O'Keefe Ford   Apt. 790       39283
# 4  -4.541598251928605    IL  98764 Mante Trafficway  Suite 356       43570
#
#                                         name_address
# ...

# %%
merged_df_name_address = pd.merge( df1,csv_file, on = 'name_address',how='inner')

# %%
merged_df_name_address.size
# Out:
# 0

# %%
merged_df_name_address.head()
# Out:
# Empty DataFrame
# Columns: [doctor.first_name, doctor.last_name, doctor.npi, city_x, lat, state_x, street_x, street_2_x, zip_x, name_address, first_name, last_name, npi, street_y, street_2_y, city_y, state_y, zip_y]
# Index: []

# %%
df1['name_address']
# Out:
# 0        Dean_Israel_271 Annabelle Fort_Apt. 404_Port D...
# 1        Quinton_Mollie_8496 Kennedi Inlet_Suite 815_Ne...
# 2        Vincent_Abbie_210 Walsh Island_Suite 839_West ...
# 3        Gerardo_Piper_1262 O'Keefe Ford_Apt. 790_Grant...
# 4        Dean_Francesco_98764 Mante Trafficway_Suite 35...
# 5        Marshall_Cole_729 Reuben Stream_Apt. 314_Lake ...
# 6        Lawson_Lilliana_36175 Amina Mount_Apt. 256_Nor...
# 7        Coty_Brad_45963 Karli Square_Apt. 942_West Cal...
# 8        Billy_Gennaro_441 Marge Turnpike_Apt. 734_West...
# 9        Deion_Mae_91801 Jamel Port_Apt. 482_Streichche...
# 10       Zena_Deondre_570 Terrence Estate_Suite 470_Mac...
# 11       Dallin_Madyson_727 Jamir Union_Apt. 589_Fernch...
# 12       Emelia_Dahlia_23643 Laila Corner_Suite 534_Pan...
# 13       Clyde_Mayra_689 Herman Parkways_Apt. 233_Kayla...
# 14       Dannie_Aimee_70057 O'Keefe Roads_Suite 240_New...
# 15       Martine_Kiana_114 Kyra Mills_Apt. 482_Jacquesv...
# ...

# %%
csv_file['name_address']
# Out:
# 0       Ruthe_Laverne_569 glenda islands_suite 163_wil...
# 1       Marshall_Cole_59944 adaline harbor_apt. 862_ke...
# 2       Lawson_Lilliana_36175 amina mount_apt. 256_nor...
# 3       Martine_Kiana_188 walsh flat_apt. 891_yasmeens...
# 6       Granville_Benton_95496 dare rue_suite 203_octa...
# 7       Brenda_Lenna_361 justyn meadow_suite 635_steub...
# 9       Marjory_Ulices_5356 hane mountains_suite 254_e...
# 11      Kathryn_Shany_817 hammes harbor_apt. 701_dicki...
# 12      Isabelle_Nils_590 cummings union_apt. 390_daph...
# 14      Madaline_Shirley_62088 krajcik summit_apt. 534...
# 15      Khalid_Crystel_89133 schoen ferry_apt. 830_ric...
# 18      Montana_Dominic_622 reggie inlet_apt. 456_wuns...
# 19      Justice_Jessy_75693 eliseo burgs_suite 102_wit...
# 20      Maryjane_Sasha_8210 romaguera ridges_apt. 807_...
# 21      Brice_Maximillian_779 macejkovic avenue_suite ...
# 23      Deborah_Jolie_2744 kirsten plaza_suite 148_zio...
# ...

# %%
 df1.loc[df1['doctor.npi'] == '78792788275411915642']
# Out:
#   doctor.first_name doctor.last_name            doctor.npi         city  \
# 6            Lawson         Lilliana  78792788275411915642  North Daija
#
#                    lat state             street  street_2         zip  \
# 6  -5.6687886642665575    DE  36175 Amina Mount  Apt. 256  30997-4476
#
#                                         name_address
# 6  Lawson_Lilliana_36175 Amina Mount_Apt. 256_Nor...

# %%
 csv_file.loc[csv_file['npi'] == '78792788275411915642']
# Out:
#   first_name last_name                   npi             street  street_2  \
# 2     Lawson  Lilliana  78792788275411915642  36175 amina mount  apt. 256
#
#           city state         zip  \
# 2  north daija    de  30997-4476
#
#                                         name_address
# 2  Lawson_Lilliana_36175 amina mount_apt. 256_nor...

# %%
df1['name_address'].lower()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-327-c2cef342d365> in <module>()
# ----> 1 df1['name_address'].lower()
#
# ~\Google Drive\Programs\Python_Programs\better_doctor\env_better_doctor\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'lower'

# %%
df3=(df1['name_address'].apply(lambda x: x.lower()))

# %%
df3.head()
# Out:
# 0    dean_israel_271 annabelle fort_apt. 404_port d...
# 1    quinton_mollie_8496 kennedi inlet_suite 815_ne...
# 2    vincent_abbie_210 walsh island_suite 839_west ...
# 3    gerardo_piper_1262 o'keefe ford_apt. 790_grant...
# 4    dean_francesco_98764 mante trafficway_suite 35...
# Name: name_address, dtype: object

# %%
csv_file_name_address=(csv_file['name_address'].apply(lambda x: x.lower()))

# %%
csv_file_name_address.head()
# Out:
# 0    ruthe_laverne_569 glenda islands_suite 163_wil...
# 1    marshall_cole_59944 adaline harbor_apt. 862_ke...
# 2    lawson_lilliana_36175 amina mount_apt. 256_nor...
# 3    martine_kiana_188 walsh flat_apt. 891_yasmeens...
# 6    granville_benton_95496 dare rue_suite 203_octa...
# Name: name_address, dtype: object

# %%
df1 = df1.drop(['name_address'], 1).copy()

# %%
csv_file=csv_file.drop(['name_address'],1).copy()

# %%
df1.shape
# Out:
# (11231, 9)

# %%
df1['name_address']=df3

# %%
df1.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi             city  \
# 0              Dean           Israel  85103080143784778415    Port Demetris
# 1           Quinton           Mollie  36233383542350521233        Nealville
# 2           Vincent            Abbie  68951826121607537145  West Lonnieberg
# 3           Gerardo            Piper  92442805782715742535     Grantborough
# 4              Dean        Francesco  83029151715578341587        New Fredy
#
#                   lat state                  street   street_2         zip  \
# 0   -79.8757664338564    LA      271 Annabelle Fort   Apt. 404       53549
# 1   81.37417480720865    OR      8496 Kennedi Inlet  Suite 815  52665-6811
# 2   52.12502086274685    GA        210 Walsh Island  Suite 839       59104
# 3   78.53231427000821    MN       1262 O'Keefe Ford   Apt. 790       39283
# 4  -4.541598251928605    IL  98764 Mante Trafficway  Suite 356       43570
#
#                                         name_address
# ...

# %%
csv_file.head()
# Out:
#   first_name last_name                   npi                street   street_2  \
# 0      Ruthe   Laverne  44843147983186317848    569 glenda islands  suite 163
# 1   Marshall      Cole  18233577393219566041  59944 adaline harbor   apt. 862
# 2     Lawson  Lilliana  78792788275411915642     36175 amina mount   apt. 256
# 3    Martine     Kiana  23583155472740817761        188 walsh flat   apt. 891
# 6  Granville    Benton  17871640342222098849        95496 dare rue  suite 203
#
#           city state         zip
# 0     willport    nj       23453
# 1  keelingstad    al  94189-5965
# 2  north daija    de  30997-4476
# 3  yasmeenstad    nv       83568
# 6  octaviastad    il  45294-0751

# %%
csv_file['name_address']=csv_file_name_address

# %%
csv_file.head()
# Out:
#   first_name last_name                   npi                street   street_2  \
# 0      Ruthe   Laverne  44843147983186317848    569 glenda islands  suite 163
# 1   Marshall      Cole  18233577393219566041  59944 adaline harbor   apt. 862
# 2     Lawson  Lilliana  78792788275411915642     36175 amina mount   apt. 256
# 3    Martine     Kiana  23583155472740817761        188 walsh flat   apt. 891
# 6  Granville    Benton  17871640342222098849        95496 dare rue  suite 203
#
#           city state         zip  \
# 0     willport    nj       23453
# 1  keelingstad    al  94189-5965
# 2  north daija    de  30997-4476
# 3  yasmeenstad    nv       83568
# 6  octaviastad    il  45294-0751
#
#                                         name_address
# 0  ruthe_laverne_569 glenda islands_suite 163_wil...
# 1  marshall_cole_59944 adaline harbor_apt. 862_ke...
# 2  lawson_lilliana_36175 amina mount_apt. 256_nor...
# 3  martine_kiana_188 walsh flat_apt. 891_yasmeens...
# ...

# %%
 df1.loc[df1['doctor.npi'] == '78792788275411915642']
# Out:
#   doctor.first_name doctor.last_name            doctor.npi         city  \
# 6            Lawson         Lilliana  78792788275411915642  North Daija
#
#                    lat state             street  street_2         zip  \
# 6  -5.6687886642665575    DE  36175 Amina Mount  Apt. 256  30997-4476
#
#                                         name_address
# 6  lawson_lilliana_36175 amina mount_apt. 256_nor...

# %%
 csv_file.loc[csv_file['npi'] == '78792788275411915642']
# Out:
#   first_name last_name                   npi             street  street_2  \
# 2     Lawson  Lilliana  78792788275411915642  36175 amina mount  apt. 256
#
#           city state         zip  \
# 2  north daija    de  30997-4476
#
#                                         name_address
# 2  lawson_lilliana_36175 amina mount_apt. 256_nor...

# %%
merged_df_name_address = pd.merge( df1,csv_file, on = 'name_address',how='inner')

# %%
merged_df_name_address
# Out:
#     doctor.first_name doctor.last_name            doctor.npi  \
# 0              Lawson         Lilliana  78792788275411915642
# 1           Granville           Benton  17871640342222098849
# 2             Marjory           Ulices  13251241236387155567
# 3            Isabelle             Nils  41196810585374325420
# 4            Madaline          Shirley  34629375530320352466
# 5             Montana          Dominic  48581605458856137841
# 6            Maryjane            Sasha  53273831484766113262
# 7             Deborah            Jolie  72248738248131276601
# 8                Zita           Yasmin  57219924682871422273
# 9               Nella         Sheridan  63158792827720528132
# 10               Eden      Maximillian  66677748434428271659
# 11         Marguerite        Johnathan  72647478424316582314
# 12              Dylan           Shanna  11536413225685215221
# 13            Camylle            Haven  86449066566138275081
# ...

# %%
merged_df_name_address.shape
# Out:
# (414, 18)

# %%
#table = string.maketrans("","")

# %%
import string

# %%
#table = string.maketrans("","")

# %%
#merged=csv_file['name_address'].apply(lambda x: x.translate(x.maketrans("",""),string.punctuation))

# %%
#merged

# %%
csv_file['name_address']
# Out:
# 0       ruthe_laverne_569 glenda islands_suite 163_wil...
# 1       marshall_cole_59944 adaline harbor_apt. 862_ke...
# 2       lawson_lilliana_36175 amina mount_apt. 256_nor...
# 3       martine_kiana_188 walsh flat_apt. 891_yasmeens...
# 6       granville_benton_95496 dare rue_suite 203_octa...
# 7       brenda_lenna_361 justyn meadow_suite 635_steub...
# 9       marjory_ulices_5356 hane mountains_suite 254_e...
# 11      kathryn_shany_817 hammes harbor_apt. 701_dicki...
# 12      isabelle_nils_590 cummings union_apt. 390_daph...
# 14      madaline_shirley_62088 krajcik summit_apt. 534...
# 15      khalid_crystel_89133 schoen ferry_apt. 830_ric...
# 18      montana_dominic_622 reggie inlet_apt. 456_wuns...
# 19      justice_jessy_75693 eliseo burgs_suite 102_wit...
# 20      maryjane_sasha_8210 romaguera ridges_apt. 807_...
# 21      brice_maximillian_779 macejkovic avenue_suite ...
# 23      deborah_jolie_2744 kirsten plaza_suite 148_zio...
# ...

# %%
import re
regex = re.compile('[%s]' % re.escape(string.punctuation))

# %%
csv_file_no_space_corpus=csv_file['name_address'].apply(lambda x: regex.sub('', x))

# %%
csv_file_no_space_corpus
# Out:
# 0       ruthelaverne569 glenda islandssuite 163willpor...
# 1       marshallcole59944 adaline harborapt 862keeling...
# 2       lawsonlilliana36175 amina mountapt 256north da...
# 3       martinekiana188 walsh flatapt 891yasmeenstadnv...
# 6       granvillebenton95496 dare ruesuite 203octavias...
# 7       brendalenna361 justyn meadowsuite 635steuberha...
# 9       marjoryulices5356 hane mountainssuite 254elmir...
# 11      kathrynshany817 hammes harborapt 701dickinsonv...
# 12      isabellenils590 cummings unionapt 390daphneebu...
# 14      madalineshirley62088 krajcik summitapt 534kund...
# 15      khalidcrystel89133 schoen ferryapt 830richiela...
# 18      montanadominic622 reggie inletapt 456wunschhav...
# 19      justicejessy75693 eliseo burgssuite 102witting...
# 20      maryjanesasha8210 romaguera ridgesapt 807asias...
# 21      bricemaximillian779 macejkovic avenuesuite 917...
# 23      deborahjolie2744 kirsten plazasuite 148zionbur...
# ...

# %%
csv_file_no_space_corpus=csv_file_no_space_corpus.apply(lambda x: x.replace(' ', ''))

# %%
csv_file_no_space_corpus
# Out:
# 0       ruthelaverne569glendaislandssuite163willportnj...
# 1       marshallcole59944adalineharborapt862keelingsta...
# 2       lawsonlilliana36175aminamountapt256northdaijad...
# 3        martinekiana188walshflatapt891yasmeenstadnv83568
# 6       granvillebenton95496dareruesuite203octaviastad...
# 7       brendalenna361justynmeadowsuite635steuberhaven...
# 9       marjoryulices5356hanemountainssuite254elmirabo...
# 11      kathrynshany817hammesharborapt701dickinsonview...
# 12      isabellenils590cummingsunionapt390daphneeburgh...
# 14      madalineshirley62088krajciksummitapt534kundech...
# 15      khalidcrystel89133schoenferryapt830richielands...
# 18      montanadominic622reggieinletapt456wunschhavenc...
# 19      justicejessy75693eliseoburgssuite102wittingsta...
# 20      maryjanesasha8210romagueraridgesapt807asiastad...
# 21      bricemaximillian779macejkovicavenuesuite917dan...
# 23      deborahjolie2744kirstenplazasuite148zionburght...
# ...

# %%
df1_no_spaces_corpus=df1['name_address'].apply(lambda x: regex.sub('', x))

# %%
df1_no_spaces_corpus
# Out:
# 0        deanisrael271 annabelle fortapt 404port demetr...
# 1        quintonmollie8496 kennedi inletsuite 815nealvi...
# 2        vincentabbie210 walsh islandsuite 839west lonn...
# 3        gerardopiper1262 okeefe fordapt 790grantboroug...
# 4        deanfrancesco98764 mante trafficwaysuite 356ne...
# 5        marshallcole729 reuben streamapt 314lake sheil...
# 6        lawsonlilliana36175 amina mountapt 256north da...
# 7        cotybrad45963 karli squareapt 942west calistas...
# 8        billygennaro441 marge turnpikeapt 734west pene...
# 9        deionmae91801 jamel portapt 482streichchestera...
# 10       zenadeondre570 terrence estatesuite 470macejko...
# 11       dallinmadyson727 jamir unionapt 589fernchester...
# 12       emeliadahlia23643 laila cornersuite 534pansymo...
# 13       clydemayra689 herman parkwaysapt 233kaylahches...
# 14       dannieaimee70057 okeefe roadssuite 240new laur...
# 15       martinekiana114 kyra millsapt 482jacquesvillen...
# ...

# %%
df1_no_spaces_corpus=df1_no_spaces_corpus.apply(lambda x: x.replace(' ', ''))

# %%
df1_no_spaces_corpus
# Out:
# 0        deanisrael271annabellefortapt404portdemetrisla...
# 1        quintonmollie8496kennediinletsuite815nealville...
# 2        vincentabbie210walshislandsuite839westlonniebe...
# 3        gerardopiper1262okeefefordapt790grantboroughmn...
# 4        deanfrancesco98764mantetrafficwaysuite356newfr...
# 5        marshallcole729reubenstreamapt314lakesheilaaz8...
# 6        lawsonlilliana36175aminamountapt256northdaijad...
# 7        cotybrad45963karlisquareapt942westcalistasiden...
# 8        billygennaro441margeturnpikeapt734westpenelope...
# 9        deionmae91801jamelportapt482streichchesteraz58023
# 10       zenadeondre570terrenceestatesuite470macejkovic...
# 11       dallinmadyson727jamirunionapt589fernchesterid4...
# 12       emeliadahlia23643lailacornersuite534pansymouth...
# 13       clydemayra689hermanparkwaysapt233kaylahchester...
# 14       dannieaimee70057okeeferoadssuite240newlauriann...
# 15       martinekiana114kyramillsapt482jacquesvillene89...
# ...

# %%
df1 = df1.drop(['name_address'], 1).copy()

csv_file=csv_file.drop(['name_address'],1).copy()

# %%
df1['name_address']=df1_no_spaces_corpus

# %%
csv_file['name_address']=csv_file_no_space_corpus

# %%
merged_df_name_address = pd.merge( df1,csv_file, on = 'name_address',how='inner')

# %%
merged_df_name_address.shape
# Out:
# (414, 18)

# %%
df1.head()
# Out:
#   doctor.first_name doctor.last_name            doctor.npi             city  \
# 0              Dean           Israel  85103080143784778415    Port Demetris
# 1           Quinton           Mollie  36233383542350521233        Nealville
# 2           Vincent            Abbie  68951826121607537145  West Lonnieberg
# 3           Gerardo            Piper  92442805782715742535     Grantborough
# 4              Dean        Francesco  83029151715578341587        New Fredy
#
#                   lat state                  street   street_2         zip  \
# 0   -79.8757664338564    LA      271 Annabelle Fort   Apt. 404       53549
# 1   81.37417480720865    OR      8496 Kennedi Inlet  Suite 815  52665-6811
# 2   52.12502086274685    GA        210 Walsh Island  Suite 839       59104
# 3   78.53231427000821    MN       1262 O'Keefe Ford   Apt. 790       39283
# 4  -4.541598251928605    IL  98764 Mante Trafficway  Suite 356       43570
#
#                                         name_address
# ...
